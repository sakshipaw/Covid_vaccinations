# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\hp\anaconda3\lib\site-packages (5.2.2)
# Requirement already satisfied: six in c:\users\hp\anaconda3\lib\site-packages (from plotly) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\hp\anaconda3\lib\site-packages (from plotly) (8.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
from plotly.offline import download_plotlyjs, plot, init_notebook_mode, iplot

# %%
df = pd.read_csv('Covid_dataset/country_vaccinations.csv')
df
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0      Albania      ALB  2021-01-10                 0.0                0.0
# 1      Albania      ALB  2021-01-11                 NaN                NaN
# 2      Albania      ALB  2021-01-12               128.0              128.0
# 3      Albania      ALB  2021-01-13               188.0              188.0
# 4      Albania      ALB  2021-01-14               266.0              266.0
# ...        ...      ...         ...                 ...                ...
# 6103  Zimbabwe      ZWE  2021-03-08             35518.0            35518.0
# 6104  Zimbabwe      ZWE  2021-03-09             35761.0            35761.0
# 6105  Zimbabwe      ZWE  2021-03-10             35901.0            35901.0
# 6106  Zimbabwe      ZWE  2021-03-11             36019.0            36019.0
# 6107  Zimbabwe      ZWE  2021-03-12             36283.0            36283.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                         NaN                     NaN                 NaN
# 1                         NaN                     NaN                64.0
# 2                         NaN                     NaN                64.0
# 3                         NaN                    60.0                63.0
# 4                         NaN                    78.0                66.0
# ...                       ...                     ...                 ...
# 6103                      NaN                  3278.0              2009.0
# 6104                      NaN                   243.0              1526.0
# 6105                      NaN                   140.0              1133.0
# 6106                      NaN                   118.0               766.0
# 6107                      NaN                   264.0               708.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                               0.00                           0.00
# 1                                NaN                            NaN
# 2                               0.00                           0.00
# 3                               0.01                           0.01
# 4                               0.01                           0.01
# ...                              ...                            ...
# 6103                            0.24                           0.24
# 6104                            0.24                           0.24
# 6105                            0.24                           0.24
# 6106                            0.24                           0.24
# 6107                            0.24                           0.24
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                     NaN                             NaN
# 1                                     NaN                            22.0
# 2                                     NaN                            22.0
# 3                                     NaN                            22.0
# 4                                     NaN                            23.0
# ...                                   ...                             ...
# 6103                                  NaN                           135.0
# 6104                                  NaN                           103.0
# 6105                                  NaN                            76.0
# 6106                                  NaN                            52.0
# 6107                                  NaN                            48.0
#
#                vaccines         source_name  \
# 0       Pfizer/BioNTech  Ministry of Health
# 1       Pfizer/BioNTech  Ministry of Health
# 2       Pfizer/BioNTech  Ministry of Health
# 3       Pfizer/BioNTech  Ministry of Health
# 4       Pfizer/BioNTech  Ministry of Health
# ...                 ...                 ...
# 6103  Sinopharm/Beijing  Ministry of Health
# 6104  Sinopharm/Beijing  Ministry of Health
# 6105  Sinopharm/Beijing  Ministry of Health
# 6106  Sinopharm/Beijing  Ministry of Health
# 6107  Sinopharm/Beijing  Ministry of Health
#
#                                          source_website
# 0     https://shendetesia.gov.al/covid19-ministria-e...
# 1     https://shendetesia.gov.al/covid19-ministria-e...
# 2     https://shendetesia.gov.al/covid19-ministria-e...
# 3     https://shendetesia.gov.al/covid19-ministria-e...
# 4     https://shendetesia.gov.al/covid19-ministria-e...
# ...                                                 ...
# 6103  https://twitter.com/MoHCCZim/status/1370448161...
# 6104  https://twitter.com/MoHCCZim/status/1370448161...
# 6105  https://twitter.com/MoHCCZim/status/1370448161...
# 6106  https://twitter.com/MoHCCZim/status/1370448161...
# 6107  https://twitter.com/MoHCCZim/status/1370448161...
#
# [6108 rows x 15 columns]

# %%
df.describe(include='object')
# Out:
#         country iso_code        date  \
# count      6108     5752        6108
# unique      133      129          90
# top     England      GBR  2021-02-22
# freq         89       89         106
#
#                                             vaccines         source_name  \
# count                                           6108                6108
# unique                                            25                  79
# top     Moderna, Oxford/AstraZeneca, Pfizer/BioNTech  Ministry of Health
# freq                                            1549                1931
#
#                                            source_website
# count                                                6108
# unique                                                129
# top     https://coronavirus.data.gov.uk/details/health...
# freq                                                  445

# %% [markdown]
# [Here we obsereved that Moderna, Oxford and pfizer are most used vaccines, now need to check for the null values](http://)

# %%
df.isnull().sum()
# Out:
# country                                   0
# iso_code                                356
# date                                      0
# total_vaccinations                     2200
# people_vaccinated                      2627
# people_fully_vaccinated                3740
# daily_vaccinations_raw                 2810
# daily_vaccinations                      191
# total_vaccinations_per_hundred         2200
# people_vaccinated_per_hundred          2627
# people_fully_vaccinated_per_hundred    3740
# daily_vaccinations_per_million          191
# vaccines                                  0
# source_name                               0
# source_website                            0
# dtype: int64

# %%
df['total_vaccinations'].dropna(inplace = True)

# %%
df['total_vaccinations'].fillna(0,inplace=True)
df
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0      Albania      ALB  2021-01-10                 0.0                0.0
# 1      Albania      ALB  2021-01-11                 0.0                NaN
# 2      Albania      ALB  2021-01-12               128.0              128.0
# 3      Albania      ALB  2021-01-13               188.0              188.0
# 4      Albania      ALB  2021-01-14               266.0              266.0
# ...        ...      ...         ...                 ...                ...
# 6103  Zimbabwe      ZWE  2021-03-08             35518.0            35518.0
# 6104  Zimbabwe      ZWE  2021-03-09             35761.0            35761.0
# 6105  Zimbabwe      ZWE  2021-03-10             35901.0            35901.0
# 6106  Zimbabwe      ZWE  2021-03-11             36019.0            36019.0
# 6107  Zimbabwe      ZWE  2021-03-12             36283.0            36283.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                         NaN                     NaN                 NaN
# 1                         NaN                     NaN                64.0
# 2                         NaN                     NaN                64.0
# 3                         NaN                    60.0                63.0
# 4                         NaN                    78.0                66.0
# ...                       ...                     ...                 ...
# 6103                      NaN                  3278.0              2009.0
# 6104                      NaN                   243.0              1526.0
# 6105                      NaN                   140.0              1133.0
# 6106                      NaN                   118.0               766.0
# 6107                      NaN                   264.0               708.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                               0.00                           0.00
# 1                                NaN                            NaN
# 2                               0.00                           0.00
# 3                               0.01                           0.01
# 4                               0.01                           0.01
# ...                              ...                            ...
# 6103                            0.24                           0.24
# 6104                            0.24                           0.24
# 6105                            0.24                           0.24
# 6106                            0.24                           0.24
# 6107                            0.24                           0.24
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                     NaN                             NaN
# 1                                     NaN                            22.0
# 2                                     NaN                            22.0
# 3                                     NaN                            22.0
# 4                                     NaN                            23.0
# ...                                   ...                             ...
# 6103                                  NaN                           135.0
# 6104                                  NaN                           103.0
# 6105                                  NaN                            76.0
# 6106                                  NaN                            52.0
# 6107                                  NaN                            48.0
#
#                vaccines         source_name  \
# 0       Pfizer/BioNTech  Ministry of Health
# 1       Pfizer/BioNTech  Ministry of Health
# 2       Pfizer/BioNTech  Ministry of Health
# 3       Pfizer/BioNTech  Ministry of Health
# 4       Pfizer/BioNTech  Ministry of Health
# ...                 ...                 ...
# 6103  Sinopharm/Beijing  Ministry of Health
# 6104  Sinopharm/Beijing  Ministry of Health
# 6105  Sinopharm/Beijing  Ministry of Health
# 6106  Sinopharm/Beijing  Ministry of Health
# 6107  Sinopharm/Beijing  Ministry of Health
#
#                                          source_website
# 0     https://shendetesia.gov.al/covid19-ministria-e...
# 1     https://shendetesia.gov.al/covid19-ministria-e...
# 2     https://shendetesia.gov.al/covid19-ministria-e...
# 3     https://shendetesia.gov.al/covid19-ministria-e...
# 4     https://shendetesia.gov.al/covid19-ministria-e...
# ...                                                 ...
# 6103  https://twitter.com/MoHCCZim/status/1370448161...
# 6104  https://twitter.com/MoHCCZim/status/1370448161...
# 6105  https://twitter.com/MoHCCZim/status/1370448161...
# 6106  https://twitter.com/MoHCCZim/status/1370448161...
# 6107  https://twitter.com/MoHCCZim/status/1370448161...
#
# [6108 rows x 15 columns]

# %%
df['total_vaccinations'].sum()
# Out:
# 8352979291.0

# %% [markdown]
# **Total no. of people vaccinated is 8352979291.0**

# %%
df=df[df['country'].apply(lambda x: x not in ['England','Wales','Northern Ireland','Scotland'])]

# %%
df['country'].astype('string').value_counts().unique
# Out:
# <bound method Series.unique of United Kingdom    89
# Canada            89
# Russia            88
# Israel            84
# United States     83
#                   ..
# Egypt              7
# Mongolia           5
# Angola             4
# Saint Helena       1
# Honduras           1
# Name: country, Length: 129, dtype: Int64>

# %% [markdown]
# What vaccines are used and in which countries?

# %%
df['vaccines'].value_counts()
# Out:
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                                          1549
# Pfizer/BioNTech                                                                       1149
# Oxford/AstraZeneca, Pfizer/BioNTech                                                    515
# Oxford/AstraZeneca                                                                     447
# Moderna, Pfizer/BioNTech                                                               371
# Sputnik V                                                                              203
# Sinovac                                                                                197
# Pfizer/BioNTech, Sinovac                                                               146
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V                      144
# Sinopharm/Beijing                                                                      110
# Oxford/AstraZeneca, Sinopharm/Beijing                                                  106
# Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V                                        94
# EpiVacCorona, Sputnik V                                                                 88
# Johnson&Johnson, Moderna, Pfizer/BioNTech                                               83
# Oxford/AstraZeneca, Pfizer/BioNTech, Sputnik V                                          79
# Sinopharm/Beijing, Sinopharm/Wuhan, Sinovac                                             76
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V              75
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinopharm/Wuhan, Sputnik V      67
# Covaxin, Oxford/AstraZeneca                                                             57
# Oxford/AstraZeneca, Sinovac                                                             56
# Pfizer/BioNTech, Sinopharm/Beijing                                                      45
# Pfizer/ BioNTech, Sinopharm/Beijing                                                     33
# Johnson&Johnson                                                                         25
# Sinopharm/Beijing, Sputnik V                                                            21
# Moderna                                                                                 16
# Name: vaccines, dtype: int64

# %%
df["iso_code"].dropna(axis=0,inplace=True)
# Out:
# <ipython-input-35-e525126be947>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df1=df[['country','iso_code','vaccines']]

# %%
df3 = df1.groupby("country").max()
df3
# Out:
#                iso_code                                   vaccines
# country
# Albania             ALB                            Pfizer/BioNTech
# Algeria             DZA                                  Sputnik V
# Andorra             AND                            Pfizer/BioNTech
# Angola              AGO                         Oxford/AstraZeneca
# Anguilla            AIA                         Oxford/AstraZeneca
# ...                 ...                                        ...
# United Kingdom      GBR        Oxford/AstraZeneca, Pfizer/BioNTech
# United States       USA  Johnson&Johnson, Moderna, Pfizer/BioNTech
# Uruguay             URY                   Pfizer/BioNTech, Sinovac
# Venezuela           VEN                                  Sputnik V
# Zimbabwe            ZWE                          Sinopharm/Beijing
#
# [129 rows x 2 columns]

# %% [markdown]
# **What country vaccinated more people?**

# %%
vaccinations = df.groupby(by="country").sum()
vaccinations.head()
# Out:
#           total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# country
# Albania              82830.0            14501.0                   2316.0
# Algeria              75030.0                0.0                      0.0
# Andorra              20107.0            15145.0                   2436.0
# Angola                6169.0             6169.0                      0.0
# Anguilla              8032.0             8032.0                      0.0
#
#           daily_vaccinations_raw  daily_vaccinations  \
# country
# Albania                   2897.0             19311.0
# Algeria                     30.0             69070.0
# Andorra                      0.0              3357.0
# Angola                       0.0              6168.0
# Anguilla                  1421.0              4083.0
#
#           total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# country
# Albania                             2.89                           0.50
# Algeria                             0.17                           0.00
# Andorra                            26.02                          19.60
# Angola                              0.02                           0.02
# Anguilla                           53.54                          53.54
#
#           people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# country
# Albania                                  0.08                          6708.0
# Algeria                                  0.00                          1568.0
# Andorra                                  3.16                         43446.0
# Angola                                   0.00                           189.0
# Anguilla                                 0.00                        272164.0

# %%
vaccinations.sort_values(by="total_vaccinations", ascending=False, inplace=True)
vaccinations.head()
# Out:
#                 total_vaccinations  people_vaccinated  \
# country
# United States         2.867864e+09       2.040570e+09
# United Kingdom        8.293203e+08       7.904030e+08
# India                 5.200359e+08       4.580560e+08
# Israel                3.814093e+08       2.442200e+08
# Turkey                2.732764e+08       1.782388e+08
#
#                 people_fully_vaccinated  daily_vaccinations_raw  \
# country
# United States               793643798.0              88559147.0
# United Kingdom               38917217.0              22081632.0
# India                        61979871.0              27754140.0
# Israel                      137189251.0               9211106.0
# Turkey                       45300233.0              10742277.0
#
#                 daily_vaccinations  total_vaccinations_per_hundred  \
# country
# United States           94004025.0                          857.50
# United Kingdom          23986675.0                         1221.66
# India                   24667468.0                           37.69
# Israel                   9023802.0                         4406.55
# Turkey                  10967584.0                          324.04
#
#                 people_vaccinated_per_hundred  \
# country
# United States                          610.18
# United Kingdom                        1164.27
# India                                   33.18
# Israel                                2821.55
# Turkey                                 211.33
#
#                 people_fully_vaccinated_per_hundred  \
# country
# United States                                237.29
# United Kingdom                                57.31
# India                                          4.48
# Israel                                      1585.00
# Turkey                                        53.71
#
#                 daily_vaccinations_per_million
# country
# United States                         281079.0
# United Kingdom                        353337.0
# India                                  17873.0
# Israel                               1042545.0
# Turkey                                130045.0

# %% [markdown]
# **Here we obsereved United states has vaccinated more people**

# %% [markdown]
# **What country is vaccinated a larger percent from its population?**

# %%
people_vaccinated = df[['country', 'total_vaccinations_per_hundred']]
people_vaccinated.head()
people_vaccinated.max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of        country  total_vaccinations_per_hundred
# 0      Albania                            0.00
# 1      Albania                             NaN
# 2      Albania                            0.00
# 3      Albania                            0.01
# 4      Albania                            0.01
# ...        ...                             ...
# 6103  Zimbabwe                            0.24
# 6104  Zimbabwe                            0.24
# 6105  Zimbabwe                            0.24
# 6106  Zimbabwe                            0.24
# 6107  Zimbabwe                            0.24
#
# [5752 rows x 2 columns]>

# %%
people_vacc_grouped = people_vaccinated.groupby("country").mean()
people_vacc_grouped.head()
# Out:
#           total_vaccinations_per_hundred
# country
# Albania                         0.137619
# Algeria                         0.056667
# Andorra                         2.891111
# Angola                          0.010000
# Anguilla                       13.385000

# %%
people_vacc_grouped.sort_values(by="total_vaccinations_per_hundred", ascending=False, inplace=True)
people_vacc_grouped.head()
# Out:
#                       total_vaccinations_per_hundred
# country
# Gibraltar                                  68.111356
# Israel                                     52.458929
# Seychelles                                 46.474865
# United Arab Emirates                       40.175224
# Falkland Islands                           31.076667

# %% [markdown]
# **Gilbraltat vaccinated large percent of population**
